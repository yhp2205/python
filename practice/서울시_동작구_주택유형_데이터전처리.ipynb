# %% [markdown]
# <a href="https://colab.research.google.com/github/yhp2205/python/blob/main/practice/%EC%84%9C%EC%9A%B8%EC%8B%9C_%EB%8F%99%EC%9E%91%EA%B5%AC_%EC%A3%BC%ED%83%9D%EC%9C%A0%ED%98%95_%EB%8D%B0%EC%9D%B4%ED%84%B0%EC%A0%84%EC%B2%98%EB%A6%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas Practice

# %% [markdown]
# ## 서울시 아파트 유형 데이터
# - 데이터 출처: 공공데이터포털
# - https://www.data.go.kr/data/15066101/fileData.do

# %% [markdown]
# ### 1. 사용할 라이브러리 불러오기

# %%
import pandas as pd
import numpy as np

# pd.set_option('display.max_rows', 10)
# pd.set_option('display.max_columns', 20)

# %%
# 한글 폰트 설치
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 18 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-nanum all 20200506-1 [10.3 MB]
# Fetched 10.3 MB in 0s (51.6 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# ...

# %%
import matplotlib.pyplot as plt

plt.rc('font', family='NanumBarunGothic')

# %% [markdown]
# ### 2. 데이터 불러오기

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
apartPath = '/content/drive/MyDrive/2023 구글클라우드인공지능과정/코드/공공데이터/02. 서울특별시 동작구_주택유형별 위치 정보 및 세대수 현황_20210825.csv'

# %%
apart = pd.read_csv(apartPath, encoding = 'cp949')

# %% [markdown]
# ### 3. 데이터프레임 정보를 확인해주세요

# %%
apart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167 entries, 0 to 166
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   연번      167 non-null    int64
#  1   분류      167 non-null    object
#  2   건물명     167 non-null    object
#  3   행정동     167 non-null    object
#  4   주소      167 non-null    object
#  5   세대수     167 non-null    int64
#  6   위도      163 non-null    float64
#  7   경도      163 non-null    float64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 10.6+ KB

# %% [markdown]
# ### 4. 누락 데이터 처리

# %% [markdown]
# - isnull() 누락 데이터 확인
# - notnull() 누락 데이터가 아닌 것만 확인
# - dropna() 누락 데이터 삭제
# - fillna() 누락 데이터 대체

# %% [markdown]
# #### 4-1. 누락 데이터가 있는 데이터 프레임만 출력해주세요

# %%
# 특정 메서드를 이용해 nan 값이 포함된 행만 선택
apart[apart['위도'].isnull()]
# Out:
#      연번    분류           건물명     행정동                                주소  세대수  \
# 18    19   아파트    관악현대(관악구)  상도1동\r        서울특별시 동작구 상도로 421\r관악로 304  405
# 20    21   아파트  관악현대아파트201동    상도1동             서울특별시 동작구 사당로24길 10-5   38
# 111  112   아파트    대방동신일해피트리     대방동  서울특별시 동작구 여의대방로62길 7\r여의대방로62길 8  130
# 158  159  연립주택       태평빌라주택    사당1동               서울특별시 동작구 사당동 282-6   21
#
#      위도  경도
# 18  NaN NaN
# 20  NaN NaN
# 111 NaN NaN
# 158 NaN NaN

# %%
# loc 를 이용해 nan 값인 행만 선택
apart.loc[apart['위도'].isnull()]
# Out:
#      연번    분류           건물명     행정동                                주소  세대수  \
# 18    19   아파트    관악현대(관악구)  상도1동\r        서울특별시 동작구 상도로 421\r관악로 304  405
# 20    21   아파트  관악현대아파트201동    상도1동             서울특별시 동작구 사당로24길 10-5   38
# 111  112   아파트    대방동신일해피트리     대방동  서울특별시 동작구 여의대방로62길 7\r여의대방로62길 8  130
# 158  159  연립주택       태평빌라주택    사당1동               서울특별시 동작구 사당동 282-6   21
#
#      위도  경도
# 18  NaN NaN
# 20  NaN NaN
# 111 NaN NaN
# 158 NaN NaN

# %%
# iloc 를 이용해 nan 값인 행만 선택
apart.iloc[apart[apart['위도'].isnull()].index]
# Out:
#      연번    분류           건물명     행정동                                주소  세대수  \
# 18    19   아파트    관악현대(관악구)  상도1동\r        서울특별시 동작구 상도로 421\r관악로 304  405
# 20    21   아파트  관악현대아파트201동    상도1동             서울특별시 동작구 사당로24길 10-5   38
# 111  112   아파트    대방동신일해피트리     대방동  서울특별시 동작구 여의대방로62길 7\r여의대방로62길 8  130
# 158  159  연립주택       태평빌라주택    사당1동               서울특별시 동작구 사당동 282-6   21
#
#      위도  경도
# 18  NaN NaN
# 20  NaN NaN
# 111 NaN NaN
# 158 NaN NaN

# %% [markdown]
# #### 4-2. 누락 데이터가 있는 데이터 프레임 중, 한 개를 선택하여 NaN 값을 채워주세요

# %%
# 특정 조건 데이터프레임 필터링
# df['column] == 'value'
apart.loc[[20],['위도','경도']]=[apart['위도'].mean(), apart['경도'].mean()]

# %% [markdown]
# #### 4-3. 다시 누락 데이터가 있는 데이터 프레임만 출력해주세요

# %%
# 다시 nan 값 데이터 확인
apart[apart['위도'].isnull()]
# Out:
#      연번    분류         건물명     행정동                                주소  세대수  위도  \
# 18    19   아파트  관악현대(관악구)  상도1동\r        서울특별시 동작구 상도로 421\r관악로 304  405 NaN
# 111  112   아파트  대방동신일해피트리     대방동  서울특별시 동작구 여의대방로62길 7\r여의대방로62길 8  130 NaN
# 158  159  연립주택     태평빌라주택    사당1동               서울특별시 동작구 사당동 282-6   21 NaN
#
#      경도
# 18  NaN
# 111 NaN
# 158 NaN

# %% [markdown]
# #### 4-4. 누락 데이터가 있는 행을 모두 삭제해주세요

# %%
apart.dropna(inplace = True)

# %% [markdown]
# #### 4-5. 데이터 프레임의 정보를 출력해주세요

# %%
apart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 164 entries, 0 to 166
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   연번      164 non-null    int64
#  1   분류      164 non-null    object
#  2   건물명     164 non-null    object
#  3   행정동     164 non-null    object
#  4   주소      164 non-null    object
#  5   세대수     164 non-null    int64
#  6   위도      164 non-null    float64
#  7   경도      164 non-null    float64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 11.5+ KB

# %% [markdown]
# #### 5. 특정 컬럼에 불필요한 문자열이 들어간 경우가 있습니다. 불필요한 문자열을 제거해주세요.

# %%
#apart['건물명'] = apart['건물명'].to_string()
#apart['건물명'] = apart['건물명'].str.strip('\r')
#apart.info()

# %%
type(apart['건물명'])
# Out:
# pandas.core.series.Series

# %%
apart.loc[apart[apart['건물명'].str.contains('\r')].index, '건물명'] = apart[apart['건물명'].str.contains('\r')]['건물명'].str.split("\r").str[0]

# %%
apart.loc[apart[apart['행정동'].str.contains('\r')].index, '행정동'] = apart[apart['행정동'].str.contains('\r')]['행정동'].str.split("\r").str[0]

# %%
apart.loc[apart[apart['주소'].str.contains('\r')].index, '주소'] = apart[apart['주소'].str.contains('\r')]['주소'].str.split("\r").str[0]

# %%
apart.head()
# Out:
#    연번   분류       건물명    행정동                      주소   세대수         위도  \
# 0    1  아파트    노량진우성  노량진1동      서울특별시 동작구 만양로8길 50   901  37.510304
# 1    2  아파트    노량진삼익  노량진1동        서울특별시 동작구 만양로 84   175  37.511367
# 2    3  아파트  신동아리버파크  노량진1동        서울특별시 동작구 만양로 19  2621  37.507073
# 3    4  아파트  노량진쌍용예가  노량진1동  서울특별시 동작구 장승배기로16길 134   299  37.510265
# 4    5  아파트     형인한강  노량진1동        서울특별시 동작구 만양로 36    73  37.507664
#
#            경도
# 0  126.946866
# 1  126.945226
# 2  126.945718
# 3  126.943676
# 4  126.948235

# %% [markdown]
# #### 6. 컬럼 이름을 아래와 같이 변경해주세요
#
# ```
# "연번": "num"
# "분류": "type"
# "건물명": "name"
# "행정동": "town"
# "주소": "address"
# "세대수": "pop"
# "위도": "lat"
# "경도": "lng"
# ```

# %%
apart.columns
# Out:
# Index(['연번 ', '분류 ', '건물명', '행정동', '주소', '세대수', '위도', '경도'], dtype='object')

# %%
apart.columns = ['num', 'type', 'name', 'town', 'address', 'pop', 'lat', 'lng']

# %%
apart.columns
# Out:
# Index(['num', 'type', 'name', 'town', 'address', 'pop', 'lat', 'lng'], dtype='object')

# %%
apart.head()
# Out:
#    num type     name   town                 address   pop        lat  \
# 0    1  아파트    노량진우성  노량진1동      서울특별시 동작구 만양로8길 50   901  37.510304
# 1    2  아파트    노량진삼익  노량진1동        서울특별시 동작구 만양로 84   175  37.511367
# 2    3  아파트  신동아리버파크  노량진1동        서울특별시 동작구 만양로 19  2621  37.507073
# 3    4  아파트  노량진쌍용예가  노량진1동  서울특별시 동작구 장승배기로16길 134   299  37.510265
# 4    5  아파트     형인한강  노량진1동        서울특별시 동작구 만양로 36    73  37.507664
#
#           lng
# 0  126.946866
# 1  126.945226
# 2  126.945718
# 3  126.943676
# 4  126.948235

# %% [markdown]
# #### 7. num 컬럼을 삭제해주세요.

# %%
apart.drop([apart.columns[0]], axis = 1, inplace = True)

# %%
apart.head()
# Out:
#   type     name   town                 address   pop        lat         lng
# 0  아파트    노량진우성  노량진1동      서울특별시 동작구 만양로8길 50   901  37.510304  126.946866
# 1  아파트    노량진삼익  노량진1동        서울특별시 동작구 만양로 84   175  37.511367  126.945226
# 2  아파트  신동아리버파크  노량진1동        서울특별시 동작구 만양로 19  2621  37.507073  126.945718
# 3  아파트  노량진쌍용예가  노량진1동  서울특별시 동작구 장승배기로16길 134   299  37.510265  126.943676
# 4  아파트     형인한강  노량진1동        서울특별시 동작구 만양로 36    73  37.507664  126.948235

# %% [markdown]
# #### 8. type 별로 세대수(pop)를 출력해주세요

# %%
apart.groupby(by = 'type').sum('pop')
# Out:
#         pop          lat           lng
# type
# 아파트   57966  4987.249387  16884.430804
# 연립주택    648   749.906322   2539.084857
# 주상복합   2047   412.424783   1396.254376
